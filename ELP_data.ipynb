# %%
import pandas as pd

# load data
df = pd.read_csv('./data/ELP.csv')
df.head()
# Out:
#    3645  knw            !Xun  \
# 0  3956  bpk           'Ôrôê
# 1  1933  taa  (Lower) Tanana
# 2  3581  aas           Aasáx
# 3  2011  abg           Abaga
# 4  3584  abf     Abai Sungai
#
#   Ju; !Xun (Ekoka); Kung-Ekoka; !Kung; Ekoka-!Xû; Kung; !Ku; !Xu; !Hu; Qxü !Khung; !Xung; Ekoka;  \
# 0                       Orowe; Boewe; Neukaledonien;
# 1                                                NaN
# 2  Asax; Asá; Aasá; Assa; Asak; "Ndorobo"; "Dorob...
# 3                                                NaN
# 4                                                NaN
#
#   Vulnerable (20 percent certain, based on the evidence available)  \
# 0  Endangered (20 percent certain, based on the e...
# 1  Critically Endangered (80 percent certain, bas...
# 2                                           Dormant
# 3  Critically Endangered (20 percent certain, bas...
# 4  Endangered (20 percent certain, based on the e...
#
#   14,000-18,000                                               Kx'a  \
# ...

# %%
df.columns = ['ID', 'ph1', 'ph2', 'ph3', 'Degree of endangerment', 'Number of speakers', 'ph4', 'ph5', 'ph6', 'ph7', 'Countries', 'Countinent', 'Coordinates']
df.head()
# Out:
#      ID  ph1             ph2  \
# 0  3956  bpk           'Ôrôê
# 1  1933  taa  (Lower) Tanana
# 2  3581  aas           Aasáx
# 3  2011  abg           Abaga
# 4  3584  abf     Abai Sungai
#
#                                                  ph3  \
# 0                       Orowe; Boewe; Neukaledonien;
# 1                                                NaN
# 2  Asax; Asá; Aasá; Assa; Asak; "Ndorobo"; "Dorob...
# 3                                                NaN
# 4                                                NaN
#
#                               Degree of endangerment Number of speakers  \
# 0  Endangered (20 percent certain, based on the e...                590
# 1  Critically Endangered (80 percent certain, bas...                 25
# 2                                           Dormant                   0
# 3  Critically Endangered (20 percent certain, bas...                  5
# 4  Endangered (20 percent certain, based on the e...               <500
#
# ...
